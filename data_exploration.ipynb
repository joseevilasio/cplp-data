# %% [markdown]
# ## Projeto - Estatuto de Igualdade de Direitos e Deveres
# ### Exploração de Dados

# %%
import pandas as pd

# %%
df = pd.read_csv("assets/merge/merge.csv", sep=";")
df.head()
# Out:
#                 search_range  \
# 0  [2021-01-01]-[2021-05-31]
# 1  [2021-01-01]-[2021-05-31]
# 2  [2021-01-01]-[2021-05-31]
# 3  [2021-01-01]-[2021-05-31]
# 4  [2021-01-01]-[2021-05-31]
#
#                                          description  \
# 0  Despacho n.º 5332/2021 - Diário da República n...
# 1  Despacho n.º 5332/2021 - Diário da República n...
# 2  Despacho n.º 5332/2021 - Diário da República n...
# 3  Despacho n.º 5332/2021 - Diário da República n...
# 4  Despacho n.º 5332/2021 - Diário da República n...
#
#                                            link_page  \
# 0  https://diariodarepublica.pt/dr/detalhe/despac...
# 1  https://diariodarepublica.pt/dr/detalhe/despac...
# 2  https://diariodarepublica.pt/dr/detalhe/despac...
# 3  https://diariodarepublica.pt/dr/detalhe/despac...
# 4  https://diariodarepublica.pt/dr/detalhe/despac...
#
#                             name  birth_date  extract_complete
# 0    João Lucas Santana do Carmo  06/08/1998              True
# ...

# %%
df["length_name"] = len(df["name"])
df.head()
# Out:
#                 search_range  \
# 0  [2021-01-01]-[2021-05-31]
# 1  [2021-01-01]-[2021-05-31]
# 2  [2021-01-01]-[2021-05-31]
# 3  [2021-01-01]-[2021-05-31]
# 4  [2021-01-01]-[2021-05-31]
#
#                                          description  \
# 0  Despacho n.º 5332/2021 - Diário da República n...
# 1  Despacho n.º 5332/2021 - Diário da República n...
# 2  Despacho n.º 5332/2021 - Diário da República n...
# 3  Despacho n.º 5332/2021 - Diário da República n...
# 4  Despacho n.º 5332/2021 - Diário da República n...
#
#                                            link_page  \
# 0  https://diariodarepublica.pt/dr/detalhe/despac...
# 1  https://diariodarepublica.pt/dr/detalhe/despac...
# 2  https://diariodarepublica.pt/dr/detalhe/despac...
# 3  https://diariodarepublica.pt/dr/detalhe/despac...
# 4  https://diariodarepublica.pt/dr/detalhe/despac...
#
#                             name  birth_date  extract_complete  length_name
# ...
